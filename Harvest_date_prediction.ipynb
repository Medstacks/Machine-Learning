# %%
import pandas as pd
import pickle
import datetime
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split as split
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("harvest_prediction_dataset_nigeria.csv")
df
# Out:
#     farmer_id     crop_type planting_date harvesting_date  duration_days  \
# 0    FARM0001       Cassava    2023-05-21      2024-02-18            273
# 1    FARM0002        Tomato    2023-02-22      2023-05-16             83
# 2    FARM0003          Rice    2023-02-17      2023-05-29            101
# 3    FARM0004        Carrot    2023-01-14      2023-04-03             79
# 4    FARM0005       Sorghum    2023-10-29      2024-03-01            124
# ..        ...           ...           ...             ...            ...
# 822  FARM0823          Okra    2023-12-04      2024-02-06             64
# 823  FARM0824         Maize    2023-01-25      2023-05-11            106
# 824  FARM0825        Carrot    2023-12-21      2024-03-02             72
# 825  FARM0826       Cassava    2023-12-03      2024-10-17            319
# 826  FARM0827  Sweet Potato    2023-12-21      2024-04-27            128
#
#        state season
# 0      Gombe    Dry
# 1    Katsina  Rainy
# 2      Ekiti    Dry
# 3        Edo  Rainy
# 4     Jigawa    Dry
# ..       ...    ...
# 822    Benue  Rainy
# 823   Sokoto  Rainy
# 824   Ebonyi    Dry
# 825    Kwara  Rainy
# 826    Gombe  Rainy
#
# [827 rows x 7 columns]

# %%
df["crop_type"].unique()
# Out:
# array(['Cassava', 'Tomato', 'Rice', 'Carrot', 'Sorghum', 'Pepper',
#        'Cowpea', 'Yam', 'Okra', 'Groundnut', 'Onion', 'Millet',
#        'Cucumber', 'Sweet Potato', 'Cocoa', 'Maize', 'Oil Palm',
#        'Soybean'], dtype=object)

# %%
df["planting_month"] = df["planting_date"].str[5:7]
df["planting_month"] = df["planting_month"].apply(lambda x: str(x))

# %%
df.planting_dat
# Out:
# 0      2023-05-21
# 1      2023-02-22
# 2      2023-02-17
# 3      2023-01-14
# 4      2023-10-29
#           ...
# 822    2023-12-04
# 823    2023-01-25
# 824    2023-12-21
# 825    2023-12-03
# 826    2023-12-21
# Name: planting_date, Length: 827, dtype: object

# %%
df_1 = df.drop(columns = ["farmer_id", "harvesting_date", "planting_date"])

# %%
df_2 = pd.get_dummies(df_1)
df_2 = df_2.replace(True, 1).replace(False, 0)
df_2
# Out:
#      duration_days  crop_type_Carrot  crop_type_Cassava  crop_type_Cocoa  \
# 0              273                 0                  1                0
# 1               83                 0                  0                0
# 2              101                 0                  0                0
# 3               79                 1                  0                0
# 4              124                 0                  0                0
# ..             ...               ...                ...              ...
# 822             64                 0                  0                0
# 823            106                 0                  0                0
# 824             72                 1                  0                0
# 825            319                 0                  1                0
# 826            128                 0                  0                0
#
#      crop_type_Cowpea  crop_type_Cucumber  crop_type_Groundnut  \
# 0                   0                   0                    0
# 1                   0                   0                    0
# 2                   0                   0                    0
# 3                   0                   0                    0
# 4                   0                   0                    0
# ..                ...                 ...                  ...
# 822                 0                   0                    0
# 823                 0                   0                    0
# 824                 0                   0                    0
# 825                 0                   0                    0
# 826                 0                   0                    0
#
#      crop_type_Maize  crop_type_Millet  crop_type_Oil Palm  ...  \
# 0                  0                 0                   0  ...
# 1                  0                 0                   0  ...
# 2                  0                 0                   0  ...
# 3                  0                 0                   0  ...
# 4                  0                 0                   0  ...
# ..               ...               ...                 ...  ...
# 822                0                 0                   0  ...
# 823                1                 0                   0  ...
# 824                0                 0                   0  ...
# 825                0                 0                   0  ...
# 826                0                 0                   0  ...
#
#      planting_month_03  planting_month_04  planting_month_05  \
# 0                    0                  0                  1
# 1                    0                  0                  0
# 2                    0                  0                  0
# 3                    0                  0                  0
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 822                  0                  0                  0
# 823                  0                  0                  0
# 824                  0                  0                  0
# 825                  0                  0                  0
# 826                  0                  0                  0
#
#      planting_month_06  planting_month_07  planting_month_08  \
# 0                    0                  0                  0
# 1                    0                  0                  0
# 2                    0                  0                  0
# 3                    0                  0                  0
# 4                    0                  0                  0
# ..                 ...                ...                ...
# 822                  0                  0                  0
# 823                  0                  0                  0
# 824                  0                  0                  0
# 825                  0                  0                  0
# 826                  0                  0                  0
#
#      planting_month_09  planting_month_10  planting_month_11  \
# 0                    0                  0                  0
# 1                    0                  0                  0
# 2                    0                  0                  0
# 3                    0                  0                  0
# 4                    0                  1                  0
# ..                 ...                ...                ...
# 822                  0                  0                  0
# 823                  0                  0                  0
# 824                  0                  0                  0
# 825                  0                  0                  0
# 826                  0                  0                  0
#
#      planting_month_12
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 822                  1
# 823                  0
# 824                  1
# 825                  1
# 826                  1
#
# [827 rows x 65 columns]

# %%
saved_columns = df_2.columns.tolist()

# %%
X = df_2.drop(columns = "duration_days")
y = df_2.duration_days

# %%
x_train, x_test, y_train, y_test = split(X, y, test_size = 0.3, random_state = 42)

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)
# Out:
# 0.950331265170593

# %%
base_learners = [
    ("LR", LinearRegression()),
    ("RFR", RandomForestRegressor(n_estimators= 50, max_depth= None, random_state= 42)),
    ("Ridge", Ridge(max_iter = 50)),
    ("Ada", AdaBoostRegressor(n_estimators = 50, learning_rate= 0.1)),
    ("KNN", KNeighborsRegressor(n_neighbors= 5))
]

stacking_model = StackingRegressor(estimators= base_learners, final_estimator= LinearRegression())
stacking_model.fit(x_train, y_train)
# Out:
# StackingRegressor(estimators=[('LR', LinearRegression()),
#                               ('RFR',
#                                RandomForestRegressor(n_estimators=50,
#                                                      random_state=42)),
#                               ('Ridge', Ridge(max_iter=50)),
#                               ('Ada', AdaBoostRegressor(learning_rate=0.1)),
#                               ('KNN', KNeighborsRegressor())],
#                   final_estimator=LinearRegression())

# %%
stacking_model.score(x_test, y_test)
# Out:
# 0.9459461242028392

# %%
stacking_model.score(x_train, y_train)
# Out:
# 0.9332077606049652

# %%
stacking_model.predict(x_train.iloc[5:10])
# Out:
# array([ 53.62931907, 110.32092248,  67.84288157,  67.64941294,
#        306.32532312])

# %%
x_train.iloc[5:10]
# Out:
#      crop_type_Carrot  crop_type_Cassava  crop_type_Cocoa  crop_type_Cowpea  \
# 132                 0                  0                0                 0
# 462                 0                  0                0                 0
# 730                 1                  0                0                 0
# 442                 1                  0                0                 0
# 41                  0                  1                0                 0
#
#      crop_type_Cucumber  crop_type_Groundnut  crop_type_Maize  \
# 132                   0                    0                0
# 462                   0                    0                0
# 730                   0                    0                0
# 442                   0                    0                0
# 41                    0                    0                0
#
#      crop_type_Millet  crop_type_Oil Palm  crop_type_Okra  ...  \
# 132                 0                   0               1  ...
# 462                 0                   0               0  ...
# 730                 0                   0               0  ...
# 442                 0                   0               0  ...
# 41                  0                   0               0  ...
#
#      planting_month_03  planting_month_04  planting_month_05  \
# 132                  0                  0                  0
# 462                  0                  0                  0
# 730                  0                  0                  0
# 442                  0                  0                  0
# 41                   0                  0                  0
#
#      planting_month_06  planting_month_07  planting_month_08  \
# 132                  0                  0                  0
# 462                  0                  0                  0
# 730                  0                  0                  0
# 442                  0                  0                  1
# 41                   0                  0                  1
#
#      planting_month_09  planting_month_10  planting_month_11  \
# 132                  0                  1                  0
# 462                  0                  0                  0
# 730                  0                  0                  0
# 442                  0                  0                  0
# 41                   0                  0                  0
#
#      planting_month_12
# 132                  0
# 462                  0
# 730                  0
# 442                  0
# 41                   0
#
# [5 rows x 64 columns]

# %%
stacking_model.fit(X, y)
# Out:
# StackingRegressor(estimators=[('LR', LinearRegression()),
#                               ('RFR',
#                                RandomForestRegressor(n_estimators=50,
#                                                      random_state=42)),
#                               ('Ridge', Ridge(max_iter=50)),
#                               ('Ada', AdaBoostRegressor(learning_rate=0.1)),
#                               ('KNN', KNeighborsRegressor())],
#                   final_estimator=LinearRegression())

# %%
with open("harvest_model_columns.pkl", "wb") as f:
    pickle.dump(saved_columns, f)

# %%
with open("harvest_day_model.pkl", "wb") as f:
    pickle.dump(stacking_model, f)
